# %% [markdown]
# **Assignment IV---Data Visualization with Matplotlib and Seaborn**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Create Dataset as follow's**

# %%
x = [1, 2, 3, 4, 5]
y = [1, 5, 4, 7, 4]

# %% [markdown]
# ***Q1***: Plot Line chart with following
#
# 1.   Line Style dotted and Line-color should be red
# 2.   X label name = x
# 3.   Y label name = y
# 4.   Add title as Example plot
# 5.   Add a circle marker.
# 6.   Line marker color as red
# 7.   Line width should be 3

# %%
plt.plot(x)
plt.plot(y,'o--r',lw=3,ms=8)

plt.xlabel('X')
plt.ylabel('Y')

plt.title("Example Plot")
plt.legend(['x', 'y'])

# %% [markdown]
# ***Q2***: Use a proper plot to know the relationship between the variables sepal_length and petal_length from the iris data
# Comment on your result.

# %%
flowers_df = sns.load_dataset("iris")

# %%
sns.scatterplot(flowers_df.petal_length,flowers_df.sepal_length,  hue=flowers_df.species);
# Out:
# c:\Users\kasth\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Enter your Comment : : : My Result Shows that the Virginica has the long petal and Sepal length, In next place versicolor has 2nd long petal and Sepal Length, setosa has small Petal and Sepal Length by comparing the relationship between petal_length and sepal_length by using scatterrplot

# %% [markdown]
# ***Q3***:  Visualizing the multidimensional relationships among the vaiable in a dataset "tips" according to the variable "time"***( Hint: hue='time')***

# %%
tips_df = sns.load_dataset("tips");

# %%
sns.pairplot(tips_df, hue='time');

# %% [markdown]
# ***Q4*** : Write code to produce the below plot (***Hint: Use sns.relplot***)
#
# ![image.png](data:image/png;base64,...)

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='total_bill',y='tip',hue='day',data=tips_df);

# %% [markdown]
# ***Q5 ***: Produce the plot below with your code by using the dataset named 'titanic' which is available in Seaborn dataset
#
#
# 1.   Include Legend
# 2.   Set ci parameter as 95
#
#
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# load dataset
titanic = sns.load_dataset('titanic')
# Write your code
sns.barplot(x=titanic.sex,y=titanic.survived,hue='class',data=titanic,ci=95);

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
